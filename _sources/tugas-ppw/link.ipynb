# %% [markdown]
# # Link Aplikasi

# %% [markdown]
# Klasifikasi Berita : https://huggingface.co/spaces/rifqi-qi/news-classification
#
# Klasifikasi Berita dengan reduksi dimensi : https://huggingface.co/spaces/rifqi-qi/classification-svd
#
# Ringkasan Dokumen : https://huggingface.co/spaces/rifqi-qi/summary-text
