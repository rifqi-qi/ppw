# %% [markdown]
# # Link Aplikasi

# %% [markdown]
# Tugas 3 : Klasifikasi Berita : https://huggingface.co/spaces/rifqi-qi/news-classification
#
# Tugas 4 : Ringkasan Dokumen : https://huggingface.co/spaces/rifqi-qi/summary-text
#
# Tugas 7 : Klasifikasi Berita dengan reduksi dimensi : https://huggingface.co/spaces/rifqi-qi/classification-svd
#
# Tugas 8 : Klasifikasi Berita Fuzzy C-Means : https://huggingface.co/spaces/rifqi-qi/Fuzzy_Classifications
